# %% [markdown]
# # Nich + Price

# %%
#run generate_output.py before running this file
#(takes about 30min)

# %% [markdown]
# ## Prep data

# %%
import numpy as np
import pandas as pd
accuracy_df=pd.read_csv('accuracy_df.csv',header=0,index_col=0)
accuracy_df.columns=['Pwy','pcomplex','operon','regulator_name','kegg_modules']
precision_df=pd.read_csv('precision_df.csv',header=0,index_col=0)
precision_df.columns=['Pwy','pcomplex','operon','regulator_name','kegg_modules']

# %%
rowIndex=np.resize(['Nichols','Nichols + Price'], 12)
rowIndex_method=['Logistic Regression','Logistic Regression',
                 'Decision Tree','Decision Tree',
                 'Random Forest','Random Forest',
                 'Gradient Boosting','Gradient Boosting',
                 'SVM','SVM',
                 'CNN', 'CNN']

# %%
#accuracy
accuracy_df.index=rowIndex
accuracy_df['rowIndex_method']=rowIndex_method
accuracy_df=accuracy_df.set_index([accuracy_df.index,'rowIndex_method'])
accuracy_df
# Out:
#                                      Pwy  pcomplex  operon  regulator_name  \
#                 rowIndex_method
# Nichols         Logistic Regression  0.8       1.0   0.875        0.576923
# Nichols + Price Logistic Regression  0.8       1.0   0.750        0.615385
# Nichols         Decision Tree        0.6       0.9   0.500        0.538462
# Nichols + Price Decision Tree        0.6       0.8   0.500        0.423077
# Nichols         Random Forest        0.7       1.0   1.000        0.730769
# Nichols + Price Random Forest        0.6       1.0   1.000        0.461538
# Nichols         Gradient Boosting    0.8       0.9   1.000        0.615385
# Nichols + Price Gradient Boosting    0.6       0.9   1.000        0.461538
# Nichols         SVM                  0.8       1.0   0.875        0.500000
# Nichols + Price SVM                  0.8       1.0   0.750        0.653846
# Nichols         CNN                  0.8       1.0   0.875        0.653846
# Nichols + Price CNN                  0.7       1.0   0.625        0.730769
#
#                                      kegg_modules
#                 rowIndex_method
# Nichols         Logistic Regression         1.000
# Nichols + Price Logistic Regression         0.875
# Nichols         Decision Tree               0.750
# Nichols + Price Decision Tree               0.875
# Nichols         Random Forest               0.875
# Nichols + Price Random Forest               0.875
# Nichols         Gradient Boosting           0.875
# Nichols + Price Gradient Boosting           0.875
# Nichols         SVM                         0.875
# Nichols + Price SVM                         0.875
# Nichols         CNN                         1.000
# Nichols + Price CNN                         0.625

# %%
#precision
precision_df.index=rowIndex
precision_df['rowIndex_method']=rowIndex_method
precision_df=precision_df.set_index([precision_df.index,'rowIndex_method'])
precision_df
# Out:
#                                        Pwy  pcomplex   operon  regulator_name  \
#                 rowIndex_method
# Nichols         Logistic Regression  0.820  1.000000  0.90625        0.602564
# Nichols + Price Logistic Regression  0.820  1.000000  0.75000        0.604701
# Nichols         Decision Tree        0.600  0.933333  0.50000        0.549650
# Nichols + Price Decision Tree        0.590  0.825000  0.50000        0.430819
# Nichols         Random Forest        0.750  1.000000  1.00000        0.743007
# Nichols + Price Random Forest        0.600  1.000000  1.00000        0.468483
# Nichols         Gradient Boosting    0.825  0.916667  1.00000        0.650350
# Nichols + Price Gradient Boosting    0.600  0.916667  1.00000        0.469891
# Nichols         SVM                  0.800  1.000000  0.90625        0.503846
# Nichols + Price SVM                  0.800  1.000000  0.75000        0.663736
# Nichols         CNN                  0.825  1.000000  0.90625        0.654808
# Nichols + Price CNN                  0.750  1.000000  0.62500        0.743631
#
#                                      kegg_modules
#                 rowIndex_method
# Nichols         Logistic Regression      1.000000
# Nichols + Price Logistic Regression      0.900000
# Nichols         Decision Tree            0.791667
# Nichols + Price Decision Tree            0.916667
# Nichols         Random Forest            0.900000
# Nichols + Price Random Forest            0.900000
# Nichols         Gradient Boosting        0.916667
# Nichols + Price Gradient Boosting        0.916667
# Nichols         SVM                      0.916667
# Nichols + Price SVM                      0.900000
# Nichols         CNN                      1.000000
# Nichols + Price CNN                      0.466667

# %%
df=accuracy_df
dataset='Nichols'
metric="Accuracy"


df_subset=np.array([indices[0] for indices in df.index])==dataset
df_subset=df.iloc[df_subset,:]
plt.ylim(bottom=0, top=20)

x=['Pathway','protein complex','operon','regulon','kegg modules']

for i in range(df_subset.shape[0]):
    y=df_subset.iloc[i,:]
    plt.scatter(x, y)
    plt.plot(x, y,alpha=0.5)

plt.gca().legend(('Logistic Regression','Decision Tree','Random Forest','Gradient Boosting','SVM','CNN'),prop={'size': 8})
plt.title(metric+' - '+dataset)
plt.ylabel(metric)

plt.savefig(metric+dataset+'.png', dpi=300)

# %%
df=precision_df
dataset='Nichols'
metric="Precision"


df_subset=np.array([indices[0] for indices in df.index])==dataset
df_subset=df.iloc[df_subset,:]

x=['Pathway','protein complex','operon','regulon','kegg modules']

for i in range(df_subset.shape[0]):
    y=df_subset.iloc[i,:]
    plt.scatter(x, y)
    plt.plot(x, y,alpha=0.5)

plt.gca().legend(('Logistic Regression','Decision Tree','Random Forest','Gradient Boosting','SVM','CNN'),prop={'size': 8})
plt.title(metric+' - '+dataset)
plt.ylabel(metric)

plt.savefig(metric+dataset+'.png', dpi=300)

# %%
df=accuracy_df
dataset='Nichols + Price'
metric="Accuracy"


df_subset=np.array([indices[0] for indices in df.index])==dataset
df_subset=df.iloc[df_subset,:]

x=['Pathway','protein complex','operon','regulon','kegg modules']

for i in range(df_subset.shape[0]):
    y=df_subset.iloc[i,:]
    plt.scatter(x, y)
    plt.plot(x, y,alpha=0.5)

plt.gca().legend(('Logistic Regression','Decision Tree','Random Forest','Gradient Boosting','SVM','CNN'),prop={'size': 8})
plt.title(metric+' - '+dataset)
plt.ylabel(metric)

plt.savefig(metric+dataset+'.png', dpi=300)

# %%
df=precision_df
dataset='Nichols + Price'
metric="Precision"


df_subset=np.array([indices[0] for indices in df.index])==dataset
df_subset=df.iloc[df_subset,:]

x=['Pathway','protein complex','operon','regulon','kegg modules']

for i in range(df_subset.shape[0]):
    y=df_subset.iloc[i,:]
    plt.scatter(x, y)
    plt.plot(x, y,alpha=0.5)

plt.gca().legend(('Logistic Regression','Decision Tree','Random Forest','Gradient Boosting','SVM','CNN'),prop={'size': 8})
plt.title(metric+' - '+dataset)
plt.ylabel(metric)

plt.savefig(metric+dataset+'.png', dpi=300)

# %%
# %pip install --upgrade matplotlib
# Out:
# Collecting matplotlib
#   Using cached https://files.pythonhosted.org/packages/a0/76/68bc3374ffa2d8d3dfd440fe94158fa8aa2628670fa38bdaf186c9af0d94/matplotlib-3.1.2-cp37-cp37m-macosx_10_9_x86_64.whl
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /Users/peterwu/opt/anaconda3/envs/R_and_python/lib/python3.7/site-packages (from matplotlib) (2.4.5)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /Users/peterwu/opt/anaconda3/envs/R_and_python/lib/python3.7/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /Users/peterwu/opt/anaconda3/envs/R_and_python/lib/python3.7/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in /Users/peterwu/opt/anaconda3/envs/R_and_python/lib/python3.7/site-packages (from matplotlib) (1.17.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /Users/peterwu/opt/anaconda3/envs/R_and_python/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied, skipping upgrade: setuptools in /Users/peterwu/opt/anaconda3/envs/R_and_python/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (42.0.1.post20191125)
# Requirement already satisfied, skipping upgrade: six in /Users/peterwu/opt/anaconda3/envs/R_and_python/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.13.0)
# Installing collected packages: matplotlib
#   Found existing installation: matplotlib 3.1.1
#     Uninstalling matplotlib-3.1.1:
#       Successfully uninstalled matplotlib-3.1.1
# Successfully installed matplotlib-3.1.2
# Note: you may need to restart the kernel to use updated packages.
