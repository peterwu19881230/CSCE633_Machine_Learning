# %% [markdown]
# # CSCE 633 Machine Learning project proposal – Classification of bacterial genes by high-throughput phenotype data

# %% [markdown]
# ## Data preparation

# %%
from urllib.request import urlopen
import pandas as pd

#data=urlopen('https://github.com/peterwu19881230/CSCE633_Machine_Learning/blob/master/final_project/Nich_Price_quantitative.txt')
pd.read_csv('https://github.com/peterwu19881230/CSCE633_Machine_Learning/blob/master/final_project/Nich_Price_quantitative.csv',header=0)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-20-2360b7928516> in <module>()
#       3
#       4 #data=urlopen('https://github.com/peterwu19881230/CSCE633_Machine_Learning/blob/master/final_project/Nich_Price_quantitative.txt')
# ----> 5 pd.read_csv('https://github.com/peterwu19881230/CSCE633_Machine_Learning/blob/master/final_project/Nich_Price_quantitative.csv',header=0)
#
# ...

# %% [markdown]
# ### Unsupervised learning

# %% [markdown]
# ### Supervised learning

# %% [markdown]
# ### Discussion
