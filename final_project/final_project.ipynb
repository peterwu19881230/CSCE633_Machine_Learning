# %% [markdown]
# # CSCE 633 Machine Learning project proposal – Classification of bacterial genes by high-throughput phenotype data

# %% [markdown]
# ## Data preparation

# %%
# !git clone https://github.com/peterwu19881230/CSCE633_Machine_Learning
# !pip install -q xlrd
# Out:
# Cloning into 'CSCE633_Machine_Learning'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 64 (delta 23), reused 41 (delta 13), pack-reused 0
# Unpacking objects: 100% (64/64), done.

# %%
import pandas as pd
# !ls CSCE633_Machine_Learning/final_project/
#df=pd.read_csv('CSCE633_Machine_Learning/final_project/Nich_Price_quantitative.csv',header=None,index_col=0)
#df.shape

annotation_dummies=pd.read_csv('CSCE633_Machine_Learning/final_project/annot_dummies.csv',header=None,index_col=0)
annotation_dummies.shape
# Out:
#  final_project.ipynb		'Project Proposal CSCE 633 FA 19.pdf'
#  Nich_Price_quantitative.csv	 project_proposal.docx
#  Nich_Price_quantitative.RData	 project_proposal.pdf
#  parse_data.R			 read_me.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-69-9e813d311ff4> in <module>()
#       4 #df.shape
#       5
# ----> 6 annotation_dummies=pd.read_csv('CSCE633_Machine_Learning/final_project/annot_dummies.csv',header=None,index_col=0)
#       7 annotation_dummies.shape
#
# ...

# %% [markdown]
# ### Unsupervised learning

# %% [markdown]
# ### Supervised learning

# %% [markdown]
# ### Discussion
