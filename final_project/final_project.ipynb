# %% [markdown]
# # CSCE 633 Machine Learning project proposal – Classification of bacterial genes by high-throughput phenotype data

# %% [markdown]
# ## Data preparation

# %%
# !git clone https://github.com/peterwu19881230/CSCE633_Machine_Learning
# !pip install -q xlrd
# Out:
# Cloning into 'CSCE633_Machine_Learning'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 55 (delta 18), reused 35 (delta 11), pack-reused 0
# Unpacking objects: 100% (55/55), done.

# %%
import pandas as pd

df=pd.read_csv('CSCE633_Machine_Learning/final_project/Nich_Price_quantitative.csv',header=None,index_col=0)
df.shape

##(!) git lfs files don't show 
#annotation_dummies=pd.read_csv('CSCE633_Machine_Learning/master/final_project/annot_dummies.csv',header=None,index_col=0)
#annotation_dummies.shape
#annotation_dummies

# %% [markdown]
# ### Unsupervised learning

# %% [markdown]
# ### Supervised learning

# %% [markdown]
# ### Discussion
