# %%
mat1=data.frame(a=1:2,b=3:4)
mat2=data.frame(c=5:6,d=7:8)
mat1
mat2
rbind(mat1,mat2)

new_rbind=function(,...)

# %%
x=seq(-pi/2,pi/2,by=0.001)
y=(cos(400*x)*sqrt(cos(x))+sqrt(abs(x)))*(4-x^2)^0.1
plot(x,y,col='red',type='l')
text(0,0.75,"Hi, Taiwan. I am back!",cex=3,col="blue")
# Out:
# plot without title

# %%
pi
# Out:
# [1] 3.141593
